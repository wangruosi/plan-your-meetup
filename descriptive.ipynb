# %% [markdown]
# # Descriptive Analysis

# %%
import app.helper as h
import app.viz as viz
from bokeh.plotting import show, output_notebook

# %%
city = "Boston"
all_topics = h.load_topics() 
topics = ["career-business", "tech", "social", "sports-fitness"]
p1 = viz.daily_occurance('Boston', topics)
p2 = viz.hourly_occurance('Boston', topics)
p3 = viz.explore_venues(city)

# %%
output_notebook()
show(p1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1313">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7d9f7edf-cfee-410d-89fb-1fadb819a0f1" data-root-id="1004"></div>

# %%
show(p2)
# Out:
#   <div class="bk-root" id="7d099e3c-95cf-4cf8-9f67-f0764d8d6a5d" data-root-id="1199"></div>

# %%
show(p3)
# Out:
#   <div class="bk-root" id="9afcde36-3475-404d-b588-5be2115ff701" data-root-id="1200"></div>
